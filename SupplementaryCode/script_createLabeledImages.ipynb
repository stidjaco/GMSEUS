# %% [markdown]
# # Generate Labeled Training Images from NAIP and GM-SEUS

# %%
# Import necessary libraries
import os
import random
import rasterio
import geopandas as gpd
import numpy as np
import re
import shutil
import glob
from collections import Counter
from shapely.geometry import Point, Polygon, MultiPolygon, box
from rasterio.merge import merge
from rasterio.windows import Window
from rasterio.mask import mask
from rasterio.warp import calculate_default_transform, reproject, Resampling

# Load config file
def load_config(filename):
    config = {}
    with open(filename, 'r') as f:
        for line in f:
            # Strip whitespace and split by '='
            key, value = line.strip().split('=')
            # Try to convert to numeric values if possible
            try:
                value = float(value) if '.' in value else int(value)
            except ValueError:
                pass  # Leave as string if not a number
            config[key] = value
    return config

# %% [markdown]
# ## Set Paths and Variables

# %%
# Set folder paths
wd = r'S:\Users\stidjaco\R_files\BigPanel'
downloaded_path = os.path.join(wd, r'Data\Downloaded')
derived_path = os.path.join(wd, r'Data\Derived')
derivedTemp_path = os.path.join(derived_path, r'intermediateProducts')
figure_path = os.path.join(wd, r'Figures')

# Set a final gmseus arrays path and panels path
gmseusArraysFinalPath = os.path.join(derived_path, r'GMSEUS/GMSEUS_Arrays_Final.shp')
gmseusPanelsFinalPath = os.path.join(derived_path, r'GMSEUS/GMSEUS_Panels_Final.shp')

# # Whole labeled images path
# labelImgsWholePath = os.path.join(derived_path, r'labelImgsWhole')
# # Set out paths for images and masks
# imagesPath = os.path.join(derived_path, r'GMSEUS/LabeledImages/images') # inputs
# masksPath = os.path.join(derived_path, r'GMSEUS/LabeledImages/masks') # targets

# Whole labeled images path (custom non cloud drive -- local) and duplicate images path from GEE export tiling
labelImgsWholePath = os.path.join(r'F:\Data\BigPanel\labelImgsWhole')
duplicateOrigPath = os.path.join(r'F:\Data\BigPanel\labelImgsWhole\duplicateOrig')

# Set out paths for images and masks
imagesPath = os.path.join(r'F:\Data\BigPanel\output\images') # inputs
masksPath = os.path.join(r'F:\Data\BigPanel\output\masks') # targets

# Load the config from the text file
config = load_config(os.path.join(wd, 'Code/config.txt'))

# Load variables from the config file
overlapDist = config['overlapDist'] # 190 meters, Set a overlap distance for checking if points/mismatched geometries between Solar PV datasets are duplicates
minPanelRowArea = config['minPanelRowArea'] # 15 m2, minimum area for a single panel row from the 1st percentile panel area from Stid et al., 2022
maxPanelRowArea = config['maxPanelRowArea'] # 254 m2 95th perccentile for a single panel row from Stid et al., 2022. MSU Solar Carport has max 1890m2
minNumPanelRows = config['minNumPanelRows'] # 3 panels, minimum number of panels rows to form a ground mounted solar array, definition from Stid et al., 2022
minPmArRatio = config['minPmArRatio'] # 18.8%, 20% was minimum ratio of panel perimeter to area ratio for panels from Stid et al., 2022, MSU Solar Carport has min 18.9%
panelArrayBuff = config['panelArrayBuff'] # 10m buffer, 20m maximum distance between panel rows to form an array. We used 5m in Stid et al., 2022, but there are lower packing factors at greater latitudes (nativeID: '1229957948')
arrayArrayBuff = config['arrayArrayBuff'] # 20m buffer, 40m maximum distance between arrays subsections of the same mount type to form a complete array. In Stid et al., 2022, we used 50m, but we checked for same installation year in addition to mount type.
lengthRatioThresh = config['lengthRatioThresh']  # If length ratio < 3.0, set to dual_axis or else fixed_axis_diagonal, else single- or fixed-axis
areaRatioThresh = config['areaRatioThresh']  # If area ratio < 0.15, set to fixed_diag_axis, else dual_axis

# Set input CRS (native output from GEE) and a toCRS (EPSG:5070)
# geeCRS = 'EPSG:4326'
# toCRS = 'EPSG:5070'

# Set image resolution
res = 0.6

# Set dimensions
dim = 256 # 256x256 images

# Set the tile area proprtion: Proportional area of the array that sets the number of tiles
tileAreaProp = 0.5 # 50% of the array, so if an array is 1 km2, will generate tiles for 0.2 km2 within the array (or one for small arrays)

# %% [markdown]
# ## Helper Functions

# %%
# Function to check if folder exists, if not create it
def checkFolder(folder):
    if not os.path.exists(folder):
        os.makedirs(folder)

# Function to check for and remove erroneous geometries in arrays
def checkArrayGeometries(arrays): 
    # For a collection of reasons, array boundaries may contain erroneous geometries that result in a near-zero area, linestrings, or points. 
    # To check for and remove these, we'll explode arrays, calculate a temporary area, remove subarrays that are less than a minimum area, then dissolve by tempID.
    arrays['tempDissolveID'] = (1 + np.arange(len(arrays)))  # Create a temporary ID for dissolving
    arrays = arrays.explode(index_parts=False)
    arrays['tempArea'] = arrays['geometry'].area
    arrays = arrays[arrays['tempArea'] >= minPanelRowArea]
    arrays = arrays.dissolve(by=['tempDissolveID'], as_index=False)
    arrays = arrays.drop(columns=['tempArea', 'tempDissolveID'])
    arrays = arrays.reset_index(drop=True)
    return arrays

# Function to create an array from a set of panel rows based on the distance between them
def createArrayFromPanels(panels, buffDist, dissolveID, areaID='area'):
 
    # Count panels per group before dissolving
    panelCounts = panels.groupby(dissolveID).size().reset_index(name='numPanels')

    # Get the total area of the panels within each group (sum of area column). 
    panelAreas = panels.groupby(dissolveID)[areaID].sum().reset_index(name='pnlArea')
    
    # Buffer the geometries by buffDist, dissovle boundaries, and unbuffer by buffDist* -1. Assign the number of objects being dissovle into a numPanels column.
    arrays = panels.copy()
    arrays['geometry'] = arrays.buffer(buffDist)
    arrays = arrays.dissolve(by=[dissolveID], as_index=False)
    arrays['geometry'] = arrays.buffer(buffDist * -1)

    # Merge the panel counts and panel areas back into the dissolved array DataFrame. Select only the dissolveID and respective columns in the right df
    arrays = arrays.merge(panelCounts[[dissolveID, 'numPanels']], on=dissolveID, how='left')
    arrays = arrays.merge(panelAreas[[dissolveID, 'pnlArea']], on=dissolveID, how='left')

    # Due to the buffering and unbuffering, some mulitpolygons contain erroneous geometries that result in a near-zero area, linestrings, or points. Remove these.
    arrays = checkArrayGeometries(arrays)

    # Reset index
    arrays = arrays.reset_index(drop=True)
    return arrays

# Step 3: Reprocess and Mosaic Duplicate Files
def merge_rasters(folder_path, output_file):
    """Merges all raster files in a folder and keeps the CRS of the first image."""
    
    # Find all TIFF files in the folder
    tiff_files = glob.glob(os.path.join(folder_path, '*.tif'))
    
    if not tiff_files:
        print(f"No TIFF files found in {folder_path}. Skipping.")
        return
    
    # Open and read TIFF files
    src_files_to_mosaic = [rasterio.open(f) for f in tiff_files]
    
    # Merge files
    mosaic, out_trans = merge(src_files_to_mosaic)
    
    # Get metadata of the first file
    out_meta = src_files_to_mosaic[0].meta.copy()
    
    # Update metadata with new dimensions and transform
    out_meta.update({
        "driver": "GTiff",
        "height": mosaic.shape[1],
        "width": mosaic.shape[2],
        "transform": out_trans,
        "crs": src_files_to_mosaic[0].crs  # Keep CRS from first file
    })

    # Save mosaic
    with rasterio.open(output_file, "w", **out_meta) as dest:
        for i in range(1, mosaic.shape[0] + 1):
            dest.write(mosaic[i - 1], i)

    # Close files
    for src in src_files_to_mosaic:
        src.close()

    print(f"Mosaic created: {output_file}")

# %% [markdown]
# # Process Imagery into Images and Masks

# %% [markdown]
# ## Setup

# %%
# Check if folders exist
checkFolder(imagesPath)
checkFolder(masksPath)

# Call gmseus arrays and panels
gmseusArrays = gpd.read_file(gmseusArraysFinalPath)
gmseusPanels = gpd.read_file(gmseusPanelsFinalPath)

# Select panel-rows where Source is "CCVPV" or "gmseus"
gmseusPanels = gmseusPanels[(gmseusPanels['Source'] == 'CCVPV') | (gmseusPanels['Source'] == 'gmseus')]

# Create arrays from panels
gmseusPanelsArrays = createArrayFromPanels(gmseusPanels, panelArrayBuff, 'arrayID', 'rowArea')

# Limit gmseusPanelsArrays to arrays with at least 10 numPanels
gmseusPanelsArrays = gmseusPanelsArrays[gmseusPanelsArrays['numPanels'] >= 10]

# Calculate a totArea column for each array
gmseusPanelsArrays['totArea'] = gmseusPanelsArrays['geometry'].area

# Set number of tiles to generate per array
tileArea = dim * dim * res * res  # Area of each tile in square meters

# Set the number of tiles to be (totArea / tileArea) * tileAreaProp OR 1 if the result is less than 1
gmseusPanelsArrays['numTiles'] = gmseusPanelsArrays['totArea'].apply(lambda x: max(1, int((x / tileArea) * tileAreaProp)))

# Print the sum of the number of tiles
print("Total number of image & mask pairs to generate: ", gmseusPanelsArrays['numTiles'].sum())

# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ ## Check for Tiled GEE Exports and Mosaic

# Due to export file size limitations, GEE can tile images on export resulting in multiple .tif files for a single arrayID. 
# We do not want to duplicate the number of tiles for this array for an inappropriate amount of area only because there are multiple files. 
# Thus, we mosaic them here, saving the originals. 

# Get filenames in the labelImgsWholePath
labelImgsWholeFiles = os.listdir(labelImgsWholePath)

# Extract arrayID from each filename. array_id is the integer value between 'id' and '.tif', but can also look like this id14432-0000000000-0000000000.tif where the arrayID is 14432
arrayIDs = []
file_map = {}  # Store filenames by arrayID
for f in labelImgsWholeFiles:
    match = re.search(r'id(\d+)', f)
    if match:
        array_id = int(match.group(1))
        arrayIDs.append(array_id)
        file_map.setdefault(array_id, []).append(f)

# Find duplicates
arrayID_counts = Counter(arrayIDs)
duplicateIDs = [arrayID for arrayID, count in arrayID_counts.items() if count > 1]

# # Print the number of duplicates
# print("Number of duplicate array whole tiffs (from GEE export tiling): ", len(duplicateIDs))
# # # Print the number of labelImgsWholeFiles that contain 0000000000
# # print("Number of labelImgsWholeFiles that contain 0000000000 (tiled images): ", len([f for f in labelImgsWholeFiles if '0000000000' in f]))
# # # Print all filenames that contain 0000000000
# # print([f for f in labelImgsWholeFiles if '0000000000' in f])

# ~~~~~~~~~~~~~~~~~~~~~~~~ Considered mosaicing duplicate, too memory intensive

# # Check if folders exist
# checkFolder(duplicateOrigPath)
# Move duplicate files to duplicateOrigPath folder to save them
# for array_id in duplicateIDs:
#     for filename in file_map[array_id]:
#         src_path = os.path.join(labelImgsWholePath, filename)
#         dest_path = os.path.join(duplicateOrigPath, filename)
#         shutil.move(src_path, dest_path)  # Move file
#         print(f"Moved {filename} to {duplicateOrigPath}")
# # Merge duplicate files
# for array_id in duplicateIDs:
#     folder_path = duplicateOrigPath
#     output_file = os.path.join(labelImgsWholePath, f"id{array_id}_mosaic.tif")
#     # Merge and save
#     merge_rasters(folder_path, output_file)

# ~~~~~~~~~~~~~~~~~~~~~~~~ We now simply adjust numTiles by image tile area within following loop
# Out:
# Total number of image & mask pairs to generate:  17586

# %% [markdown]
# ## Split & Tile Whole Imagery

# %%
# This cell takes ~150 minutes to run 

# Loop through each labeled image and extract tiles 
for image_filename in os.listdir(labelImgsWholePath):
    if not image_filename.endswith('.tif'):
        continue  # Skip non-TIFF files

    # Extract arrayID from filename. array_id is the integer value between 'id' and '.tif', but can also look like this id14432-0000000000-0000000000.tif where the arrayID is 14432
    match = re.search(r'id(\d+)', image_filename)  # Looks for 'id' followed by digits
    if match:
        array_id = int(match.group(1))  # Convert to integer
    else:
        print(f"Warning: Could not extract array ID from {image_filename}. Skipping.")
        continue  # Skip this file if no match found

    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Call in and prepare the image

    # Open the geotiff image
    image_path = os.path.join(labelImgsWholePath, image_filename)
    with rasterio.open(image_path) as src:
        print(f"Processing {image_filename} - Original CRS: {src.crs}")

        # Use the image's existing CRS (don't force-set it). If it's missing, print a warning and pass this image
        src_crs = src.crs
        if not src_crs:
            print(f"Warning: No CRS found for image {image_filename}. Skipping.")
            continue

        # Set toCRS to the image's CRS
        toCRS = src_crs

        # Set reprojected_src to the original src
        reprojected_src = src

        # # Check if reprojection is needed -- For now, maintain the original CRS
        # if src_crs != toCRS:
        #     print(f"Reprojecting {image_filename} to {toCRS}...")

        #     # Calculate new transformation
        #     transform, width, height = calculate_default_transform(
        #         src_crs, toCRS, src.width, src.height, *src.bounds
        #     )

        #     # Update metadata for reprojected image
        #     kwargs = src.meta.copy()
        #     kwargs.update({
        #         'crs': toCRS,
        #         'transform': transform,
        #         'width': width,
        #         'height': height
        #     })

        #     # Perform reprojection and keep MemoryFile open
        #     memfile = rasterio.MemoryFile()
        #     with memfile.open(**kwargs) as dst:
        #         for i in range(1, src.count + 1):
        #             reproject(
        #                 source=rasterio.band(src, i),
        #                 destination=rasterio.band(dst, i),
        #                 src_transform=src.transform,
        #                 src_crs=src_crs,
        #                 dst_transform=transform,
        #                 dst_crs=toCRS,
        #                 resampling=Resampling.nearest
        #             )

        #     # Keep the MemoryFile dataset open for reading
        #     reprojected_src = memfile.open()  # Keep file open!
        # else:
        #     reprojected_src = src  # Use original if no reprojection needed

        # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Get array geometry, number of tiles, and image bounds

        # Find the corresponding polygon for this array ID -- from gmseusPanelsArrays, to ensure panel-rows exist in image region
        array_row = gmseusPanelsArrays[gmseusPanelsArrays['arrayID'] == array_id]
        if array_row.empty:
            print(f"Warning: No matching polygon found for array ID {array_id}. Skipping.")
            continue

        # Trasform array_row to desired CRS and get the geometry
        array_row = array_row.to_crs(toCRS)
        array_geom = array_row.geometry.values[0]

        # Get the number of tiles to generate for this array
        numTilesArray = array_row['numTiles'].values[0]

        # Get raster bounds as a polygon
        image_bounds = reprojected_src.bounds
        image_poly = box(image_bounds.left, image_bounds.bottom, image_bounds.right, image_bounds.top)

        # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Check for duplicate images and area, adjust numTiles accordingly

        # Adjust numTiles based on proportional area if this array has duplicates
        if array_id in duplicateIDs:
            # Get all files for this duplicate array_id
            duplicate_files = [f for f in os.listdir(labelImgsWholePath) if re.search(r'id(\d+)', f) and int(re.search(r'id(\d+)', f).group(1)) == array_id]

            # Calculate current image area
            image_area = image_poly.area  # Area of the image portion that contains valid panels

            # Calculate total area across all duplicate images
            total_image_area = sum(box(*rasterio.open(os.path.join(labelImgsWholePath, f)).bounds).area for f in duplicate_files)

            # Adjust `numTiles` proportionally
            if total_image_area > 0:
                numTiles = max(1, int((image_area / total_image_area) * numTilesArray))  # Ensure at least 1 tile
            else:
                numTiles = 1  # Fallback to avoid division by zero

            # Print original numTiles and adjusted numTiles
            print(f"Original numTiles for {image_filename}: {numTilesArray}")    
            print(f"Adjusted numTiles for {image_filename}: {numTiles} based on proportional area.")
        else:
            numTiles = numTilesArray  # If no duplicate, keep original value

        # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Generate random points within the array polygon and create tiles

        # Check if array polygon intersects the image
        if not array_geom.intersects(image_poly):
            print(f"Warning: Array {array_id} does not overlap with image {image_filename}. Skipping.")
            continue  # Skip this image

        # Generate numTiles number of random points inside the polygon
        for tile_idx in range(numTiles):
            while True:
                # Generate a random point within the bounds of the polygon
                minx, miny, maxx, maxy = array_geom.bounds
                random_point = Point(random.uniform(minx, maxx), random.uniform(miny, maxy))
                
                # Ensure point is inside the polygon
                if array_geom.contains(random_point):
                    break
            
            # Convert point to pixel coordinates using the correct DatasetReader
            x, y = random_point.x, random_point.y
            row, col = reprojected_src.index(x, y) 

            # Define window for cropping the raster (ensuring it fits inside the raster bounds)
            window = Window(col - dim // 2, row - dim // 2, dim, dim)

            # Read bands
            img_bands = reprojected_src.read([1, 2, 3, 4], window=window)  # Assuming bands are R, G, B, N
            mask_band = reprojected_src.read(5, window=window)  # Assuming mask is stored in band 5

            # Save image bands
            img_outfile = os.path.join(imagesPath, f"id{array_id}_tile{tile_idx}.tif")
            with rasterio.open(
                img_outfile,
                'w',
                driver='GTiff',
                height=dim,
                width=dim,
                count=4,
                dtype=img_bands.dtype,
                crs=toCRS,
                transform=reprojected_src.window_transform(window)
            ) as dst:
                for i in range(4):
                    dst.write(img_bands[i], i + 1)

            # Save mask band
            mask_outfile = os.path.join(masksPath, f"id{array_id}_tile{tile_idx}.tif")
            with rasterio.open(
                mask_outfile,
                'w',
                driver='GTiff',
                height=dim,
                width=dim,
                count=1,
                dtype=mask_band.dtype,
                crs=toCRS,
                transform=reprojected_src.window_transform(window)
            ) as dst:
                dst.write(mask_band, 1)

            # Print message -- check
            # print(f"Saved image: {img_outfile} and mask: {mask_outfile}")

        # Close reprojected dataset after processing all tiles
        reprojected_src.close()
        if 'memfile' in locals():  # Close MemoryFile if it was used
            memfile.close()
# Out:
# Processing id100.tif - Original CRS: EPSG:26910
# Processing id1001.tif - Original CRS: EPSG:26918
# Processing id10014.tif - Original CRS: EPSG:26918
# Processing id10029.tif - Original CRS: EPSG:26910
# Processing id1003.tif - Original CRS: EPSG:26918
# Processing id10036.tif - Original CRS: EPSG:26919
# Processing id10038.tif - Original CRS: EPSG:26917
# Processing id1004.tif - Original CRS: EPSG:26918
# Processing id10045.tif - Original CRS: EPSG:26916
# Processing id10056.tif - Original CRS: EPSG:26918
# Processing id10058.tif - Original CRS: EPSG:26917
# Processing id10059.tif - Original CRS: EPSG:26918
# Processing id1006.tif - Original CRS: EPSG:26918
# Processing id10063.tif - Original CRS: EPSG:26917
# Processing id10065.tif - Original CRS: EPSG:26918
# Processing id10067.tif - Original CRS: EPSG:26917
# Processing id10070.tif - Original CRS: EPSG:26919
# Processing id10073.tif - Original CRS: EPSG:26918
# Processing id10078.tif - Original CRS: EPSG:26918
# Processing id10079.tif - Original CRS: EPSG:26914
# Processing id1008.tif - Original CRS: EPSG:26918
# Processing id10094.tif - Original CRS: EPSG:26918
# Processing id10095.tif - Original CRS: EPSG:26918
# Processing id10097.tif - Original CRS: EPSG:26919
# Processing id101.tif - Original CRS: EPSG:26910
# Processing id1010.tif - Original CRS: EPSG:26918
# Processing id10102.tif - Original CRS: EPSG:26918
# Processing id10105.tif - Original CRS: EPSG:26918
# Processing id10106.tif - Original CRS: EPSG:26918
# Processing id10107.tif - Original CRS: EPSG:26919
# Processing id10110.tif - Original CRS: EPSG:26918
# Processing id10111.tif - Original CRS: EPSG:26916
# Processing id10113.tif - Original CRS: EPSG:26917
# Processing id10114.tif - Original CRS: EPSG:26917
# Processing id10116.tif - Original CRS: EPSG:26918
# Processing id10117.tif - Original CRS: EPSG:26914
# Processing id10118.tif - Original CRS: EPSG:26915
# Processing id1012.tif - Original CRS: EPSG:26918
# Processing id10121.tif - Original CRS: EPSG:26910
# Processing id10122.tif - Original CRS: EPSG:26916
# Processing id10128.tif - Original CRS: EPSG:26910
# Processing id10132.tif - Original CRS: EPSG:26918
# Processing id10134.tif - Original CRS: EPSG:26911
# Processing id10135.tif - Original CRS: EPSG:26911
# Processing id10136.tif - Original CRS: EPSG:26918
# Processing id10137.tif - Original CRS: EPSG:26916
# Processing id10138.tif - Original CRS: EPSG:26919
# Processing id10140.tif - Original CRS: EPSG:26914
# Processing id10143.tif - Original CRS: EPSG:26916
# Processing id10145.tif - Original CRS: EPSG:26919
# Processing id10147.tif - Original CRS: EPSG:26911
# Processing id1015.tif - Original CRS: EPSG:26918
# Processing id10154.tif - Original CRS: EPSG:26918
# Processing id10155.tif - Original CRS: EPSG:26912
# Processing id10156.tif - Original CRS: EPSG:26919
# Processing id1016.tif - Original CRS: EPSG:26918
# Processing id10162.tif - Original CRS: EPSG:26918
# Processing id10165.tif - Original CRS: EPSG:26911
# Processing id10168.tif - Original CRS: EPSG:26919
# Processing id10169.tif - Original CRS: EPSG:26916
# Processing id1017.tif - Original CRS: EPSG:26918
# Processing id10170.tif - Original CRS: EPSG:26916
# Processing id10171.tif - Original CRS: EPSG:26919
# Processing id10172.tif - Original CRS: EPSG:26911
# Processing id10176.tif - Original CRS: EPSG:26911
# Processing id10177.tif - Original CRS: EPSG:26919
# Processing id10178.tif - Original CRS: EPSG:26919
# Processing id10179.tif - Original CRS: EPSG:26918
# Processing id1018.tif - Original CRS: EPSG:26918
# Processing id10182.tif - Original CRS: EPSG:26919
# Processing id10183.tif - Original CRS: EPSG:26918
# Processing id10184.tif - Original CRS: EPSG:26916
# Processing id10189.tif - Original CRS: EPSG:26918
# Processing id1019.tif - Original CRS: EPSG:26918
# Processing id10190.tif - Original CRS: EPSG:26918
# Processing id10197.tif - Original CRS: EPSG:26912
# Processing id102.tif - Original CRS: EPSG:26911
# Processing id1020.tif - Original CRS: EPSG:26918
# Processing id10200.tif - Original CRS: EPSG:26917
# Processing id10204.tif - Original CRS: EPSG:26916
# Processing id10205.tif - Original CRS: EPSG:26916
# Processing id10207.tif - Original CRS: EPSG:26911
# Processing id10217.tif - Original CRS: EPSG:26911
# Processing id10218.tif - Original CRS: EPSG:26911
# Processing id10221.tif - Original CRS: EPSG:26918
# Processing id10223.tif - Original CRS: EPSG:26913
# Processing id10224.tif - Original CRS: EPSG:26918
# Processing id10225.tif - Original CRS: EPSG:26917
# Processing id10226.tif - Original CRS: EPSG:26917
# Processing id10227.tif - Original CRS: EPSG:26918
# Processing id10228.tif - Original CRS: EPSG:26918
# Processing id10229.tif - Original CRS: EPSG:26918
# Processing id1023.tif - Original CRS: EPSG:26918
# Processing id10230.tif - Original CRS: EPSG:26919
# Processing id10231.tif - Original CRS: EPSG:26918
# Processing id10232.tif - Original CRS: EPSG:26918
# Processing id10234.tif - Original CRS: EPSG:26919
# Processing id10235.tif - Original CRS: EPSG:26919
# Processing id10236.tif - Original CRS: EPSG:26918
# Processing id10237.tif - Original CRS: EPSG:26918
# Processing id10238.tif - Original CRS: EPSG:26914
# Processing id10240.tif - Original CRS: EPSG:26910
# Processing id10241.tif - Original CRS: EPSG:26918
# Processing id10248.tif - Original CRS: EPSG:26918
# Processing id10249.tif - Original CRS: EPSG:26919
# Processing id10257.tif - Original CRS: EPSG:26911
# Processing id10263.tif - Original CRS: EPSG:26911
# Processing id10268.tif - Original CRS: EPSG:26914
# Processing id1027.tif - Original CRS: EPSG:26918
# Processing id1028.tif - Original CRS: EPSG:26917
# Processing id10282.tif - Original CRS: EPSG:26918
# Processing id10283.tif - Original CRS: EPSG:26918
# Processing id10284.tif - Original CRS: EPSG:26912
# Processing id10296.tif - Original CRS: EPSG:26918
# Processing id103.tif - Original CRS: EPSG:26911
# Processing id10300.tif - Original CRS: EPSG:26918
# Processing id10312.tif - Original CRS: EPSG:26918
# Processing id10323.tif - Original CRS: EPSG:26919
# Processing id10324.tif - Original CRS: EPSG:26911
# Processing id10326.tif - Original CRS: EPSG:26911
# Processing id10329.tif - Original CRS: EPSG:26911
# Processing id10332.tif - Original CRS: EPSG:26910
# Processing id10338.tif - Original CRS: EPSG:26918
# Processing id10349.tif - Original CRS: EPSG:26910
# Processing id10350.tif - Original CRS: EPSG:26919
# Processing id10354.tif - Original CRS: EPSG:26914
# Processing id10358.tif - Original CRS: EPSG:26917
# Processing id1036.tif - Original CRS: EPSG:26918
# Processing id10366.tif - Original CRS: EPSG:26918
# Processing id10368.tif - Original CRS: EPSG:26911
# Processing id10371.tif - Original CRS: EPSG:26918
# Processing id10373.tif - Original CRS: EPSG:26917
# Processing id1038.tif - Original CRS: EPSG:26918
# Processing id10384.tif - Original CRS: EPSG:26915
# Processing id1039.tif - Original CRS: EPSG:26918
# Processing id10390.tif - Original CRS: EPSG:26911
# Processing id10396.tif - Original CRS: EPSG:26918
# Processing id10397.tif - Original CRS: EPSG:26916
# Processing id10399.tif - Original CRS: EPSG:26918
# Processing id104.tif - Original CRS: EPSG:26911
# Processing id1040.tif - Original CRS: EPSG:26918
# Processing id10400.tif - Original CRS: EPSG:26911
# Processing id10402.tif - Original CRS: EPSG:26916
# Processing id10403.tif - Original CRS: EPSG:26919
# Processing id10414.tif - Original CRS: EPSG:26918
# Processing id10418.tif - Original CRS: EPSG:26919
# Processing id1042.tif - Original CRS: EPSG:26918
# Processing id10424.tif - Original CRS: EPSG:26915
# Processing id10437.tif - Original CRS: EPSG:26918
# Processing id1044.tif - Original CRS: EPSG:26918
# Processing id1045.tif - Original CRS: EPSG:26918
# Processing id10451.tif - Original CRS: EPSG:26919
# Processing id10458.tif - Original CRS: EPSG:26918
# Processing id1046.tif - Original CRS: EPSG:26918
# Processing id10461.tif - Original CRS: EPSG:26918
# Processing id1047.tif - Original CRS: EPSG:26918
# Processing id10475.tif - Original CRS: EPSG:26911
# Processing id10478.tif - Original CRS: EPSG:26918
# Processing id1048.tif - Original CRS: EPSG:26918
# Processing id10481.tif - Original CRS: EPSG:26911
# Processing id1049.tif - Original CRS: EPSG:26918
# Processing id10492.tif - Original CRS: EPSG:26911
# Processing id10495.tif - Original CRS: EPSG:26919
# Processing id10499.tif - Original CRS: EPSG:26919
# Processing id105.tif - Original CRS: EPSG:26911
# Processing id1050.tif - Original CRS: EPSG:26918
# Processing id10503.tif - Original CRS: EPSG:26918
# Processing id10511.tif - Original CRS: EPSG:26911
# Processing id10514.tif - Original CRS: EPSG:26911
# Processing id10515.tif - Original CRS: EPSG:26910
# Processing id10518.tif - Original CRS: EPSG:26917
# Processing id1052.tif - Original CRS: EPSG:26918
# Processing id10524.tif - Original CRS: EPSG:26910
# Processing id10529.tif - Original CRS: EPSG:26911
# Processing id10530.tif - Original CRS: EPSG:26918
# Processing id10531.tif - Original CRS: EPSG:26916
# Processing id10535.tif - Original CRS: EPSG:26910
# Processing id10536.tif - Original CRS: EPSG:26912
# Processing id1054.tif - Original CRS: EPSG:26918
# Processing id10544.tif - Original CRS: EPSG:26915
# Processing id10545.tif - Original CRS: EPSG:26910
# Processing id10546.tif - Original CRS: EPSG:26918
# Processing id1055.tif - Original CRS: EPSG:26918
# Processing id10553.tif - Original CRS: EPSG:26916
# Processing id10555.tif - Original CRS: EPSG:26912
# Processing id10556.tif - Original CRS: EPSG:26910
# Processing id10557.tif - Original CRS: EPSG:26912
# Processing id1056.tif - Original CRS: EPSG:26918
# Processing id10561.tif - Original CRS: EPSG:26918
# Processing id10564.tif - Original CRS: EPSG:26917
# Processing id10567.tif - Original CRS: EPSG:26918
# Processing id10570.tif - Original CRS: EPSG:26918
# Processing id10571.tif - Original CRS: EPSG:26910
# Processing id10572.tif - Original CRS: EPSG:26918
# Processing id10573.tif - Original CRS: EPSG:26911
# Processing id10577.tif - Original CRS: EPSG:26910
# Processing id10578.tif - Original CRS: EPSG:26918
# Processing id10584.tif - Original CRS: EPSG:26911
# Processing id10587.tif - Original CRS: EPSG:26919
# Processing id10589.tif - Original CRS: EPSG:26916
# Processing id1059.tif - Original CRS: EPSG:26918
# Processing id10594.tif - Original CRS: EPSG:26914
# Processing id10599.tif - Original CRS: EPSG:26911
# Processing id106.tif - Original CRS: EPSG:26911
# Processing id10602.tif - Original CRS: EPSG:26915
# Processing id10608.tif - Original CRS: EPSG:26917
# Processing id10613.tif - Original CRS: EPSG:26911
# Processing id10617.tif - Original CRS: EPSG:26918
# Processing id10619.tif - Original CRS: EPSG:26918
# Processing id10621.tif - Original CRS: EPSG:26910
# Processing id1063.tif - Original CRS: EPSG:26918
# Processing id10630.tif - Original CRS: EPSG:26911
# Processing id10631.tif - Original CRS: EPSG:26914
# Processing id10633.tif - Original CRS: EPSG:26911
# Processing id10635.tif - Original CRS: EPSG:26918
# Processing id10636.tif - Original CRS: EPSG:26917
# Processing id10637.tif - Original CRS: EPSG:26919
# Processing id10639.tif - Original CRS: EPSG:26918
# Processing id10642.tif - Original CRS: EPSG:26912
# Processing id10644.tif - Original CRS: EPSG:26914
# Processing id10645.tif - Original CRS: EPSG:26916
# Processing id10646.tif - Original CRS: EPSG:26918
# Processing id10647.tif - Original CRS: EPSG:26919
# Processing id10649.tif - Original CRS: EPSG:26918
# Processing id1065.tif - Original CRS: EPSG:26918
# Processing id10651.tif - Original CRS: EPSG:26910
# Processing id10652.tif - Original CRS: EPSG:26919
# Processing id10654.tif - Original CRS: EPSG:26910
# Processing id10655.tif - Original CRS: EPSG:26918
# Processing id10656.tif - Original CRS: EPSG:26911
# Processing id10660.tif - Original CRS: EPSG:26918
# Processing id1067.tif - Original CRS: EPSG:26918
# Processing id10672.tif - Original CRS: EPSG:26911
# Processing id10677.tif - Original CRS: EPSG:26910
# Processing id10680.tif - Original CRS: EPSG:26918
# Processing id10682.tif - Original CRS: EPSG:26910
# Processing id10687.tif - Original CRS: EPSG:26912
# Processing id10688.tif - Original CRS: EPSG:26913
# Processing id10689.tif - Original CRS: EPSG:26911
# Processing id1069.tif - Original CRS: EPSG:26918
# Processing id10690.tif - Original CRS: EPSG:26916
# Processing id10693.tif - Original CRS: EPSG:26918
# Processing id10697.tif - Original CRS: EPSG:26910
# Processing id10708.tif - Original CRS: EPSG:26911
# Processing id1071.tif - Original CRS: EPSG:26918
# Processing id10710.tif - Original CRS: EPSG:26916
# Processing id10714.tif - Original CRS: EPSG:26911
# Processing id10716.tif - Original CRS: EPSG:26910
# Processing id10729.tif - Original CRS: EPSG:26918
# Processing id1073.tif - Original CRS: EPSG:26918
# Processing id10738.tif - Original CRS: EPSG:26917
# Processing id10739.tif - Original CRS: EPSG:26911
# Processing id1074.tif - Original CRS: EPSG:26918
# Processing id10741.tif - Original CRS: EPSG:26911
# Processing id10750.tif - Original CRS: EPSG:26910
# Processing id10755.tif - Original CRS: EPSG:26911
# Processing id10766.tif - Original CRS: EPSG:26911
# Processing id10768.tif - Original CRS: EPSG:26913
# Processing id10769.tif - Original CRS: EPSG:26911
# Processing id1077.tif - Original CRS: EPSG:26918
# Processing id10771.tif - Original CRS: EPSG:26911
# Processing id10774.tif - Original CRS: EPSG:26912
# Processing id10778.tif - Original CRS: EPSG:26912
# Processing id1078.tif - Original CRS: EPSG:26918
# Processing id10786.tif - Original CRS: EPSG:26910
# Processing id10789.tif - Original CRS: EPSG:26918
# Processing id1079.tif - Original CRS: EPSG:26918
# Processing id10791.tif - Original CRS: EPSG:26912
# Processing id10793.tif - Original CRS: EPSG:26911
# Processing id10796.tif - Original CRS: EPSG:26918
# Processing id10798.tif - Original CRS: EPSG:26918
# Processing id10799.tif - Original CRS: EPSG:26918
# Processing id108.tif - Original CRS: EPSG:26911
# Processing id10816.tif - Original CRS: EPSG:26919
# Processing id10817.tif - Original CRS: EPSG:26910
# Processing id10824.tif - Original CRS: EPSG:26918
# Processing id10828.tif - Original CRS: EPSG:26914
# Processing id10829.tif - Original CRS: EPSG:26911
# Processing id1083.tif - Original CRS: EPSG:26918
# Processing id10830.tif - Original CRS: EPSG:26911
# Processing id10831.tif - Original CRS: EPSG:26910
# Processing id10836.tif - Original CRS: EPSG:26918
# Processing id10840.tif - Original CRS: EPSG:26918
# Processing id10849.tif - Original CRS: EPSG:26918
# Processing id10850.tif - Original CRS: EPSG:26919
# Processing id10851.tif - Original CRS: EPSG:26915
# Processing id10852.tif - Original CRS: EPSG:26918
# Processing id10853.tif - Original CRS: EPSG:26911
# Processing id1086.tif - Original CRS: EPSG:26918
# Processing id10870.tif - Original CRS: EPSG:26911
# Processing id10871.tif - Original CRS: EPSG:26918
# Processing id10872.tif - Original CRS: EPSG:26918
# Processing id10873.tif - Original CRS: EPSG:26915
# Processing id10876.tif - Original CRS: EPSG:26917
# Processing id10879.tif - Original CRS: EPSG:26917
# Processing id10881.tif - Original CRS: EPSG:26917
# Processing id10883.tif - Original CRS: EPSG:26910
# Processing id10884.tif - Original CRS: EPSG:26918
# Processing id10885.tif - Original CRS: EPSG:26918
# Processing id10886.tif - Original CRS: EPSG:26918
# Processing id10888.tif - Original CRS: EPSG:26917
# Processing id10889.tif - Original CRS: EPSG:26918
# Processing id1089.tif - Original CRS: EPSG:26918
# Processing id10890.tif - Original CRS: EPSG:26917
# Processing id10892.tif - Original CRS: EPSG:26917
# Processing id10893.tif - Original CRS: EPSG:26910
# Processing id10894.tif - Original CRS: EPSG:26918
# Processing id10895.tif - Original CRS: EPSG:26919
# Processing id10896.tif - Original CRS: EPSG:26919
# Processing id10897.tif - Original CRS: EPSG:26918
# Processing id10898.tif - Original CRS: EPSG:26910
# Processing id10899.tif - Original CRS: EPSG:26918
# Processing id109.tif - Original CRS: EPSG:26910
# Processing id10900.tif - Original CRS: EPSG:26917
# Processing id10902.tif - Original CRS: EPSG:26919
# Processing id10903.tif - Original CRS: EPSG:26919
# Processing id10904.tif - Original CRS: EPSG:26917
# Processing id10905.tif - Original CRS: EPSG:26917
# Processing id10906.tif - Original CRS: EPSG:26917
# Processing id10907.tif - Original CRS: EPSG:26915
# Processing id10909.tif - Original CRS: EPSG:26915
# Warning: No matching polygon found for array ID 10909. Skipping.
# Processing id10913.tif - Original CRS: EPSG:26918
# Processing id10916.tif - Original CRS: EPSG:26917
# Processing id10918.tif - Original CRS: EPSG:26918
# Processing id10920.tif - Original CRS: EPSG:26912
# Processing id10921.tif - Original CRS: EPSG:26912
# Processing id10922.tif - Original CRS: EPSG:26912
# Processing id10923.tif - Original CRS: EPSG:26911
# Processing id10924.tif - Original CRS: EPSG:26911
# Processing id10925.tif - Original CRS: EPSG:26910
# Processing id10929.tif - Original CRS: EPSG:26917
# Processing id10930.tif - Original CRS: EPSG:26918
# Processing id10931.tif - Original CRS: EPSG:26918
# Processing id10934.tif - Original CRS: EPSG:26918
# Processing id10937.tif - Original CRS: EPSG:26918
# Processing id10938.tif - Original CRS: EPSG:26917
# Processing id1094.tif - Original CRS: EPSG:26918
# Processing id10940.tif - Original CRS: EPSG:26917
# Processing id10941.tif - Original CRS: EPSG:26918
# Processing id10944.tif - Original CRS: EPSG:26918
# Processing id10945.tif - Original CRS: EPSG:26918
# Processing id1095.tif - Original CRS: EPSG:26918
# Processing id10951.tif - Original CRS: EPSG:26915
# Warning: No matching polygon found for array ID 10951. Skipping.
# Processing id10954.tif - Original CRS: EPSG:26912
# Processing id10956.tif - Original CRS: EPSG:26918
# Processing id10957.tif - Original CRS: EPSG:26918
# Processing id10958.tif - Original CRS: EPSG:26919
# Processing id10963.tif - Original CRS: EPSG:26915
# Warning: No matching polygon found for array ID 10963. Skipping.
# Processing id10965.tif - Original CRS: EPSG:26911
# Processing id10966.tif - Original CRS: EPSG:26917
# Processing id10967.tif - Original CRS: EPSG:26918
# Processing id10968.tif - Original CRS: EPSG:26918
# Processing id10969.tif - Original CRS: EPSG:26913
# Processing id10970.tif - Original CRS: EPSG:26918
# Processing id10971.tif - Original CRS: EPSG:26910
# Processing id10972.tif - Original CRS: EPSG:26917
# Processing id10974.tif - Original CRS: EPSG:26910
# Processing id10976.tif - Original CRS: EPSG:26918
# Processing id10977.tif - Original CRS: EPSG:26918
# Processing id10979.tif - Original CRS: EPSG:26917
# Processing id1098.tif - Original CRS: EPSG:26918
# Processing id10980.tif - Original CRS: EPSG:26912
# Processing id10981.tif - Original CRS: EPSG:26915
# Warning: No matching polygon found for array ID 10981. Skipping.
# Processing id10982.tif - Original CRS: EPSG:26917
# Processing id10986.tif - Original CRS: EPSG:26915
# Warning: No matching polygon found for array ID 10986. Skipping.
# Processing id10987.tif - Original CRS: EPSG:26918
# Processing id1099.tif - Original CRS: EPSG:26918
# Processing id10998.tif - Original CRS: EPSG:26911
# Processing id11.tif - Original CRS: EPSG:26910
# Processing id110.tif - Original CRS: EPSG:26910
# Processing id11002.tif - Original CRS: EPSG:26918
# Processing id11003.tif - Original CRS: EPSG:26918
# Processing id11004.tif - Original CRS: EPSG:26917
# Processing id11005.tif - Original CRS: EPSG:26919
# Processing id11006.tif - Original CRS: EPSG:26916
# Processing id11008.tif - Original CRS: EPSG:26917
# Processing id11010.tif - Original CRS: EPSG:26915
# Processing id11011.tif - Original CRS: EPSG:26911
# Processing id11015.tif - Original CRS: EPSG:26918
# Processing id11016.tif - Original CRS: EPSG:26918
# Processing id11017.tif - Original CRS: EPSG:26917
# Processing id11018.tif - Original CRS: EPSG:26919
# Processing id11019.tif - Original CRS: EPSG:26914
# Processing id1102.tif - Original CRS: EPSG:26918
# Processing id11020.tif - Original CRS: EPSG:26912
# Processing id11021.tif - Original CRS: EPSG:26913
# Processing id11023.tif - Original CRS: EPSG:26911
# Processing id11024.tif - Original CRS: EPSG:26918
# Processing id11025.tif - Original CRS: EPSG:26918
# Processing id11027.tif - Original CRS: EPSG:26910
# Processing id11028.tif - Original CRS: EPSG:26910
# Processing id11029.tif - Original CRS: EPSG:26918
# Processing id11030.tif - Original CRS: EPSG:26917
# Processing id11031.tif - Original CRS: EPSG:26917
# Processing id11034.tif - Original CRS: EPSG:26919
# Processing id11035.tif - Original CRS: EPSG:26919
# Processing id11036.tif - Original CRS: EPSG:26917
# Processing id11037.tif - Original CRS: EPSG:26917
# Processing id11045.tif - Original CRS: EPSG:26911
# Processing id11049.tif - Original CRS: EPSG:26917
# Processing id1105.tif - Original CRS: EPSG:26918
# Processing id11051.tif - Original CRS: EPSG:26910
# Processing id11052.tif - Original CRS: EPSG:26919
# Processing id11056.tif - Original CRS: EPSG:26913
# Processing id11057.tif - Original CRS: EPSG:26910
# Processing id11058.tif - Original CRS: EPSG:26910
# Processing id11059.tif - Original CRS: EPSG:26913
# Processing id1106.tif - Original CRS: EPSG:26918
# Processing id11060.tif - Original CRS: EPSG:26918
# Processing id11063.tif - Original CRS: EPSG:26911
# Processing id11064.tif - Original CRS: EPSG:26911
# Processing id11065.tif - Original CRS: EPSG:26915
# Processing id11066.tif - Original CRS: EPSG:26918
# Processing id11067.tif - Original CRS: EPSG:26918
# Processing id11069.tif - Original CRS: EPSG:26917
# Processing id11071.tif - Original CRS: EPSG:26918
# Processing id11074.tif - Original CRS: EPSG:26917
# Processing id11075.tif - Original CRS: EPSG:26917
# Processing id11076.tif - Original CRS: EPSG:26912
# Processing id11077.tif - Original CRS: EPSG:26911
# Processing id11078.tif - Original CRS: EPSG:26910
# Processing id11079.tif - Original CRS: EPSG:26916
# Processing id1108.tif - Original CRS: EPSG:26918
# Processing id11080.tif - Original CRS: EPSG:26918
# Processing id11081.tif - Original CRS: EPSG:26914
# Processing id11083.tif - Original CRS: EPSG:26911
# Processing id11084.tif - Original CRS: EPSG:26910
# Processing id11085.tif - Original CRS: EPSG:26910
# Processing id11086.tif - Original CRS: EPSG:26917
# Processing id11087.tif - Original CRS: EPSG:26917
# Processing id1109.tif - Original CRS: EPSG:26918
# Processing id11091.tif - Original CRS: EPSG:26911
# Processing id11093.tif - Original CRS: EPSG:26918
# Processing id11095.tif - Original CRS: EPSG:26911
# Processing id11097.tif - Original CRS: EPSG:26912
# Processing id11098.tif - Original CRS: EPSG:26912
# Processing id111.tif - Original CRS: EPSG:26911
# Processing id1110.tif - Original CRS: EPSG:26918
# Processing id11101.tif - Original CRS: EPSG:26916
# Processing id11102.tif - Original CRS: EPSG:26917
# Processing id11103.tif - Original CRS: EPSG:26917
# Processing id11109.tif - Original CRS: EPSG:26918
# Processing id1111.tif - Original CRS: EPSG:26918
# Processing id11110.tif - Original CRS: EPSG:26919
# Processing id11112.tif - Original CRS: EPSG:26912
# Processing id11113.tif - Original CRS: EPSG:26913
# Processing id11114.tif - Original CRS: EPSG:26912
# Processing id11115.tif - Original CRS: EPSG:26917
# Processing id11116.tif - Original CRS: EPSG:26918
# Processing id11117.tif - Original CRS: EPSG:26917
# Processing id1112.tif - Original CRS: EPSG:26918
# Processing id11120.tif - Original CRS: EPSG:26917
# Processing id11123.tif - Original CRS: EPSG:26918
# Processing id11125.tif - Original CRS: EPSG:26913
# Processing id11127.tif - Original CRS: EPSG:26918
# Processing id11128.tif - Original CRS: EPSG:26911
# Processing id11129.tif - Original CRS: EPSG:26919
# Processing id11130.tif - Original CRS: EPSG:26918
# Processing id11131.tif - Original CRS: EPSG:26919
# Processing id11132.tif - Original CRS: EPSG:26918
# Processing id11133.tif - Original CRS: EPSG:26918
# Processing id11134.tif - Original CRS: EPSG:26918
# Processing id11136.tif - Original CRS: EPSG:26911
# Processing id11137.tif - Original CRS: EPSG:26918
# Processing id11138.tif - Original CRS: EPSG:26918
# Processing id11139.tif - Original CRS: EPSG:26911
# Processing id11140.tif - Original CRS: EPSG:26918
# Processing id11142.tif - Original CRS: EPSG:26911
# Processing id11143.tif - Original CRS: EPSG:26918
# Processing id11144.tif - Original CRS: EPSG:26918
# Processing id11145.tif - Original CRS: EPSG:26919
# Processing id11146.tif - Original CRS: EPSG:26911
# Processing id11147.tif - Original CRS: EPSG:26911
# Processing id11148.tif - Original CRS: EPSG:26917
# Processing id11149.tif - Original CRS: EPSG:26912
# Processing id1115.tif - Original CRS: EPSG:26917
# Processing id11150.tif - Original CRS: EPSG:26918
# Processing id11151.tif - Original CRS: EPSG:26918
# Processing id11152.tif - Original CRS: EPSG:26919
# Processing id11153.tif - Original CRS: EPSG:26912
# Processing id11154.tif - Original CRS: EPSG:26917
# Processing id11155.tif - Original CRS: EPSG:26918
# Processing id11156.tif - Original CRS: EPSG:26917
# Processing id11157.tif - Original CRS: EPSG:26911
# Processing id11159.tif - Original CRS: EPSG:26911
# Processing id11160.tif - Original CRS: EPSG:26911
# Processing id11161.tif - Original CRS: EPSG:26916
# Processing id11162.tif - Original CRS: EPSG:26917
# Processing id11163.tif - Original CRS: EPSG:26910
# Warning: No matching polygon found for array ID 11163. Skipping.
# Processing id11165.tif - Original CRS: EPSG:26917
# Processing id11167.tif - Original CRS: EPSG:26917
# Processing id11168.tif - Original CRS: EPSG:26917
# Processing id11169.tif - Original CRS: EPSG:26917
# Warning: No matching polygon found for array ID 11169. Skipping.
# Processing id11173.tif - Original CRS: EPSG:26917
# Processing id1118.tif - Original CRS: EPSG:26918
# Processing id11187.tif - Original CRS: EPSG:26918
# Warning: No matching polygon found for array ID 11187. Skipping.
# Processing id11189.tif - Original CRS: EPSG:26919
# Processing id1119.tif - Original CRS: EPSG:26918
# Processing id11190.tif - Original CRS: EPSG:26919
# Processing id11191.tif - Original CRS: EPSG:26917
# Processing id11192.tif - Original CRS: EPSG:26918
# Processing id11193.tif - Original CRS: EPSG:26914
# Processing id11197.tif - Original CRS: EPSG:26917
# Processing id11198.tif - Original CRS: EPSG:26918
# Processing id11199.tif - Original CRS: EPSG:26917
# Processing id112.tif - Original CRS: EPSG:26911
# Processing id11200.tif - Original CRS: EPSG:26917
# Processing id11202.tif - Original CRS: EPSG:26913
# Processing id11204.tif - Original CRS: EPSG:26917
# Processing id11205.tif - Original CRS: EPSG:26917
# Processing id11207.tif - Original CRS: EPSG:26911
# Processing id11208.tif - Original CRS: EPSG:26911
# Processing id11209.tif - Original CRS: EPSG:26911
# Processing id1121.tif - Original CRS: EPSG:26918
# Processing id11211.tif - Original CRS: EPSG:26911
# Processing id11212.tif - Original CRS: EPSG:26918
# Processing id11214.tif - Original CRS: EPSG:26918
# Processing id11216.tif - Original CRS: EPSG:26918
# Processing id11217.tif - Original CRS: EPSG:26917
# Processing id11218.tif - Original CRS: EPSG:26912
# Processing id11219.tif - Original CRS: EPSG:26912
# Processing id1122.tif - Original CRS: EPSG:26918
# Processing id11220.tif - Original CRS: EPSG:26911
# Processing id11221.tif - Original CRS: EPSG:26918
# Processing id11222.tif - Original CRS: EPSG:26911
# Processing id11223.tif - Original CRS: EPSG:26911
# Processing id11225.tif - Original CRS: EPSG:26916
# Warning: No matching polygon found for array ID 11225. Skipping.
# Processing id11226.tif - Original CRS: EPSG:26912
# Processing id11227.tif - Original CRS: EPSG:26918
# Processing id11228.tif - Original CRS: EPSG:26917
# Processing id1123.tif - Original CRS: EPSG:26918
# Processing id11230.tif - Original CRS: EPSG:26911
# Processing id11231.tif - Original CRS: EPSG:26918
# Processing id11232.tif - Original CRS: EPSG:26919
# Processing id11233.tif - Original CRS: EPSG:26918
# Processing id11234.tif - Original CRS: EPSG:26918
# Processing id11235.tif - Original CRS: EPSG:26917
# Processing id11237.tif - Original CRS: EPSG:26912
# Processing id11238.tif - Original CRS: EPSG:26911
# Processing id11242.tif - Original CRS: EPSG:26917
# Processing id11243.tif - Original CRS: EPSG:26913
# Processing id11244.tif - Original CRS: EPSG:26913
# Processing id11245.tif - Original CRS: EPSG:26917
# Processing id11246.tif - Original CRS: EPSG:26917
# Processing id11247.tif - Original CRS: EPSG:26917
# Processing id11248.tif - Original CRS: EPSG:26917
# Processing id11249.tif - Original CRS: EPSG:26917
# Processing id1125.tif - Original CRS: EPSG:26918
# Processing id11250.tif - Original CRS: EPSG:26917
# Processing id11251.tif - Original CRS: EPSG:26918
# Processing id11252.tif - Original CRS: EPSG:26917
# Processing id11254.tif - Original CRS: EPSG:26917
# Processing id11256.tif - Original CRS: EPSG:26917
# Processing id11257.tif - Original CRS: EPSG:26911
# Processing id11258.tif - Original CRS: EPSG:26914
# Processing id11259.tif - Original CRS: EPSG:26917
# Processing id1126.tif - Original CRS: EPSG:26918
# Processing id11260.tif - Original CRS: EPSG:26918
# Processing id11261.tif - Original CRS: EPSG:26911
# Processing id11262.tif - Original CRS: EPSG:26917
# Processing id11263.tif - Original CRS: EPSG:26918
# Processing id11264.tif - Original CRS: EPSG:26918
# Processing id11266.tif - Original CRS: EPSG:26918
# Processing id11267.tif - Original CRS: EPSG:26918
# Processing id11269.tif - Original CRS: EPSG:26913
# Processing id11270.tif - Original CRS: EPSG:26911
# Processing id11271.tif - Original CRS: EPSG:26918
# Processing id11272.tif - Original CRS: EPSG:26918
# Processing id11273.tif - Original CRS: EPSG:26919
# Processing id11274.tif - Original CRS: EPSG:26918
# Processing id11275.tif - Original CRS: EPSG:26918
# Processing id11276.tif - Original CRS: EPSG:26918
# Processing id11277.tif - Original CRS: EPSG:26911
# Processing id11278.tif - Original CRS: EPSG:26911
# Processing id11279.tif - Original CRS: EPSG:26917
# Processing id11280.tif - Original CRS: EPSG:26918
# Processing id11281.tif - Original CRS: EPSG:26918
# Processing id11282.tif - Original CRS: EPSG:26918
# Processing id11283.tif - Original CRS: EPSG:26918
# Processing id11285.tif - Original CRS: EPSG:26918
# Processing id11288.tif - Original CRS: EPSG:26918
# Processing id11289.tif - Original CRS: EPSG:26919
# Processing id11293.tif - Original CRS: EPSG:26919
# Processing id11294.tif - Original CRS: EPSG:26918
# Processing id11295.tif - Original CRS: EPSG:26918
# Processing id11296.tif - Original CRS: EPSG:26917
# Processing id11297.tif - Original CRS: EPSG:26910
# Processing id1130.tif - Original CRS: EPSG:26918
# Processing id11305.tif - Original CRS: EPSG:26912
# Processing id11306.tif - Original CRS: EPSG:26911
# Processing id11307.tif - Original CRS: EPSG:26911
# Processing id11309.tif - Original CRS: EPSG:26912
# Processing id1131.tif - Original CRS: EPSG:26918
# Processing id11310.tif - Original CRS: EPSG:26918
# Processing id11311.tif - Original CRS: EPSG:26919
# Processing id11312.tif - Original CRS: EPSG:26918
# Processing id11314.tif - Original CRS: EPSG:26918
# Processing id11315.tif - Original CRS: EPSG:26918
# Processing id11317.tif - Original CRS: EPSG:26919
# Processing id11318.tif - Original CRS: EPSG:26918
# Processing id11319.tif - Original CRS: EPSG:26911
# Processing id11320.tif - Original CRS: EPSG:26919
# Processing id11321.tif - Original CRS: EPSG:26918
# Processing id11322.tif - Original CRS: EPSG:26917
# Processing id11323.tif - Original CRS: EPSG:26917
# Processing id11324.tif - Original CRS: EPSG:26917
# Processing id11327.tif - Original CRS: EPSG:26917
# Processing id11329.tif - Original CRS: EPSG:26919
# Processing id11330.tif - Original CRS: EPSG:26917
# Processing id11333.tif - Original CRS: EPSG:26910
# Processing id11334.tif - Original CRS: EPSG:26919
# Processing id11335.tif - Original CRS: EPSG:26918
# Processing id11336.tif - Original CRS: EPSG:26918
# Processing id11340.tif - Original CRS: EPSG:26917
# Processing id11341.tif - Original CRS: EPSG:26918
# Processing id11343.tif - Original CRS: EPSG:26918
# Processing id11346.tif - Original CRS: EPSG:26917
# Processing id11347.tif - Original CRS: EPSG:26916
# Processing id11348.tif - Original CRS: EPSG:26913
# Processing id11349.tif - Original CRS: EPSG:26917
# Processing id11350.tif - Original CRS: EPSG:26918
# Processing id11351.tif - Original CRS: EPSG:26918
# Processing id11353.tif - Original CRS: EPSG:26918
# Processing id11354.tif - Original CRS: EPSG:26918
# Processing id11356.tif - Original CRS: EPSG:26913
# Processing id11357.tif - Original CRS: EPSG:26913
# Processing id11361.tif - Original CRS: EPSG:26915
# Warning: No matching polygon found for array ID 11361. Skipping.
# Processing id11364.tif - Original CRS: EPSG:26919
# Processing id11365.tif - Original CRS: EPSG:26918
# Processing id11367.tif - Original CRS: EPSG:26915
# Warning: No matching polygon found for array ID 11367. Skipping.
# Processing id1137.tif - Original CRS: EPSG:26918
# Processing id11370.tif - Original CRS: EPSG:26917
# Processing id11373.tif - Original CRS: EPSG:26917
# Processing id11375.tif - Original CRS: EPSG:26918
# Processing id11376.tif - Original CRS: EPSG:26916
# Processing id11377.tif - Original CRS: EPSG:26910
# Processing id11378.tif - Original CRS: EPSG:26915
# Processing id11379.tif - Original CRS: EPSG:26917
# Processing id11380.tif - Original CRS: EPSG:26917
# Processing id11383.tif - Original CRS: EPSG:26918
# Processing id11389.tif - Original CRS: EPSG:26913
# Processing id11391.tif - Original CRS: EPSG:26917
# Processing id11392.tif - Original CRS: EPSG:26917
# Processing id11393.tif - Original CRS: EPSG:26915
# Processing id11396.tif - Original CRS: EPSG:26918
# Processing id11398.tif - Original CRS: EPSG:26919
# Processing id11399.tif - Original CRS: EPSG:26918
# Processing id114.tif - Original CRS: EPSG:26911
# Processing id1140.tif - Original CRS: EPSG:26918
# Processing id11400.tif - Original CRS: EPSG:26912
# Processing id11403.tif - Original CRS: EPSG:26913
# Processing id11404.tif - Original CRS: EPSG:26911
# Processing id11409.tif - Original CRS: EPSG:26917
# Processing id11410.tif - Original CRS: EPSG:26916
# Processing id11411.tif - Original CRS: EPSG:26916
# Processing id11412.tif - Original CRS: EPSG:26918
# Processing id11413.tif - Original CRS: EPSG:26918
# Processing id11414.tif - Original CRS: EPSG:26918
# Processing id11416.tif - Original CRS: EPSG:26911
# Processing id11418.tif - Original CRS: EPSG:26913
# Processing id1142.tif - Original CRS: EPSG:26918
# Processing id11420.tif - Original CRS: EPSG:26918
# Processing id11424.tif - Original CRS: EPSG:26917
# Processing id11425.tif - Original CRS: EPSG:26917
# Processing id11426.tif - Original CRS: EPSG:26918
# Processing id1143.tif - Original CRS: EPSG:26917
# Processing id11430.tif - Original CRS: EPSG:26918
# Processing id11431.tif - Original CRS: EPSG:26918
# Processing id11432.tif - Original CRS: EPSG:26914
# Processing id11433.tif - Original CRS: EPSG:26918
# Processing id11434.tif - Original CRS: EPSG:26918
# Processing id11436.tif - Original CRS: EPSG:26917
# Processing id11437.tif - Original CRS: EPSG:26918
# Processing id11438.tif - Original CRS: EPSG:26919
# Processing id11439.tif - Original CRS: EPSG:26910
# Processing id11440.tif - Original CRS: EPSG:26910
# Processing id11442.tif - Original CRS: EPSG:26913
# Processing id11444.tif - Original CRS: EPSG:26913
# Processing id11448.tif - Original CRS: EPSG:26913
# Processing id1145.tif - Original CRS: EPSG:26918
# Processing id11452.tif - Original CRS: EPSG:26918
# Processing id11453.tif - Original CRS: EPSG:26918
# Processing id11454.tif - Original CRS: EPSG:26918
# Processing id11458.tif - Original CRS: EPSG:26916
# Processing id11459.tif - Original CRS: EPSG:26917
# Processing id11460.tif - Original CRS: EPSG:26911
# Processing id11461.tif - Original CRS: EPSG:26919
# Processing id11463.tif - Original CRS: EPSG:26911
# Processing id11469.tif - Original CRS: EPSG:26918
# Processing id1147.tif - Original CRS: EPSG:26918
# Processing id11474.tif - Original CRS: EPSG:26915
# Processing id11475.tif - Original CRS: EPSG:26918
# Processing id1148.tif - Original CRS: EPSG:26918
# Processing id11484.tif - Original CRS: EPSG:26914
# Processing id11485.tif - Original CRS: EPSG:26918
# Processing id11489.tif - Original CRS: EPSG:26917
# Processing id11490.tif - Original CRS: EPSG:26917
# Processing id11491.tif - Original CRS: EPSG:26917
# Processing id11492.tif - Original CRS: EPSG:26917
# Processing id11493.tif - Original CRS: EPSG:26917
# Processing id11494.tif - Original CRS: EPSG:26917
# Processing id11495.tif - Original CRS: EPSG:26917
# Processing id11496.tif - Original CRS: EPSG:26917
# Processing id11497.tif - Original CRS: EPSG:26917
# Processing id11498.tif - Original CRS: EPSG:26917
# Processing id11499.tif - Original CRS: EPSG:26917
# Processing id115.tif - Original CRS: EPSG:26911
# Processing id11500.tif - Original CRS: EPSG:26918
# Processing id11501.tif - Original CRS: EPSG:26919
# Processing id11503.tif - Original CRS: EPSG:26917
# Processing id11504.tif - Original CRS: EPSG:26917
# Processing id11505.tif - Original CRS: EPSG:26917
# Processing id11506.tif - Original CRS: EPSG:26917
# Processing id11509.tif - Original CRS: EPSG:26918
# Processing id11510.tif - Original CRS: EPSG:26918
# Processing id11511.tif - Original CRS: EPSG:26917
# Processing id11512.tif - Original CRS: EPSG:26916
# Processing id11513.tif - Original CRS: EPSG:26919
# Processing id11514.tif - Original CRS: EPSG:26919
# Processing id11515.tif - Original CRS: EPSG:26919
# Processing id11516.tif - Original CRS: EPSG:26918
# Processing id11517.tif - Original CRS: EPSG:26912
# Processing id11520.tif - Original CRS: EPSG:26917
# Processing id11521.tif - Original CRS: EPSG:26918
# Processing id11522.tif - Original CRS: EPSG:26918
# Processing id11523.tif - Original CRS: EPSG:26917
# Processing id11524.tif - Original CRS: EPSG:26917
# Processing id11525.tif - Original CRS: EPSG:26917
# Processing id11526.tif - Original CRS: EPSG:26917
# Processing id11527.tif - Original CRS: EPSG:26917
# Processing id11529.tif - Original CRS: EPSG:26917
# Processing id11530.tif - Original CRS: EPSG:26918
# Processing id11532.tif - Original CRS: EPSG:26918
# Processing id11533.tif - Original CRS: EPSG:26917
# Processing id11534.tif - Original CRS: EPSG:26917
# Processing id11535.tif - Original CRS: EPSG:26918
# Processing id11536.tif - Original CRS: EPSG:26913
# Processing id11537.tif - Original CRS: EPSG:26917
# Processing id11538.tif - Original CRS: EPSG:26917
# Processing id11539.tif - Original CRS: EPSG:26917
# Processing id1154.tif - Original CRS: EPSG:26915
# Processing id11540.tif - Original CRS: EPSG:26917
# Processing id11541.tif - Original CRS: EPSG:26918
# Processing id11542.tif - Original CRS: EPSG:26919
# Processing id11543.tif - Original CRS: EPSG:26919
# Processing id11545.tif - Original CRS: EPSG:26917
# Processing id11547.tif - Original CRS: EPSG:26917
# Processing id11548.tif - Original CRS: EPSG:26918
# Processing id1155.tif - Original CRS: EPSG:26918
# Processing id11552.tif - Original CRS: EPSG:26918
# Processing id11555.tif - Original CRS: EPSG:26917
# Processing id11556.tif - Original CRS: EPSG:26918
# Processing id11558.tif - Original CRS: EPSG:26912
# Processing id11563.tif - Original CRS: EPSG:26918
# Processing id11565.tif - Original CRS: EPSG:26910
# Processing id11567.tif - Original CRS: EPSG:26918
# Processing id11571.tif - Original CRS: EPSG:26917
# Processing id11572.tif - Original CRS: EPSG:26918
# Processing id11573.tif - Original CRS: EPSG:26916
# Warning: No matching polygon found for array ID 11573. Skipping.
# Processing id11574.tif - Original CRS: EPSG:26911
# Processing id11575.tif - Original CRS: EPSG:26919
# Processing id11576.tif - Original CRS: EPSG:26917
# Processing id11577.tif - Original CRS: EPSG:26910
# Processing id11578.tif - Original CRS: EPSG:26918
# Processing id11579.tif - Original CRS: EPSG:26918
# Processing id1158.tif - Original CRS: EPSG:26917
# Processing id11580.tif - Original CRS: EPSG:26918
# Processing id11581.tif - Original CRS: EPSG:26913
# Processing id11582.tif - Original CRS: EPSG:26910
# Processing id11583.tif - Original CRS: EPSG:26916
# Processing id11584.tif - Original CRS: EPSG:26913
# Processing id11585.tif - Original CRS: EPSG:26918
# Processing id11587.tif - Original CRS: EPSG:26918
# Processing id11588.tif - Original CRS: EPSG:26916
# Processing id11590.tif - Original CRS: EPSG:26913
# Processing id11592.tif - Original CRS: EPSG:26918
# Processing id11593.tif - Original CRS: EPSG:26918
# Processing id11595.tif - Original CRS: EPSG:26917
# Processing id11597.tif - Original CRS: EPSG:26918
# Processing id11598.tif - Original CRS: EPSG:26912
# Processing id11599.tif - Original CRS: EPSG:26917
# Processing id116.tif - Original CRS: EPSG:26911
# Processing id1160.tif - Original CRS: EPSG:26915
# Processing id11600.tif - Original CRS: EPSG:26917
# Processing id11601.tif - Original CRS: EPSG:26917
# Processing id11602.tif - Original CRS: EPSG:26918
# Processing id11604.tif - Original CRS: EPSG:26917
# Processing id11606.tif - Original CRS: EPSG:26916
# Processing id11607.tif - Original CRS: EPSG:26919
# Processing id11608.tif - Original CRS: EPSG:26919
# Processing id11609.tif - Original CRS: EPSG:26918
# Processing id11610.tif - Original CRS: EPSG:26918
# Processing id11611.tif - Original CRS: EPSG:26917
# Processing id11612.tif - Original CRS: EPSG:26918
# Processing id11613.tif - Original CRS: EPSG:26911
# Processing id11614.tif - Original CRS: EPSG:26918
# Processing id11615.tif - Original CRS: EPSG:26917
# Processing id11616.tif - Original CRS: EPSG:26917
# Processing id11617.tif - Original CRS: EPSG:26917
# Processing id1162.tif - Original CRS: EPSG:26918
# Processing id11623.tif - Original CRS: EPSG:26918
# Processing id11624.tif - Original CRS: EPSG:26918
# Processing id11625.tif - Original CRS: EPSG:26918
# Processing id11626.tif - Original CRS: EPSG:26918
# Processing id11627.tif - Original CRS: EPSG:26918
# Processing id11628.tif - Original CRS: EPSG:26918
# Processing id11629.tif - Original CRS: EPSG:26917
# Processing id11630.tif - Original CRS: EPSG:26917
# Processing id11632.tif - Original CRS: EPSG:26917
# Processing id11633.tif - Original CRS: EPSG:26917
# Processing id11634.tif - Original CRS: EPSG:26917
# Processing id11636.tif - Original CRS: EPSG:26918
# Processing id11639-0000000000-0000000000.tif - Original CRS: EPSG:26913
# Original numTiles for id11639-0000000000-0000000000.tif: 70
# Adjusted numTiles for id11639-0000000000-0000000000.tif: 65 based on proportional area.
# Processing id11639-0000000000-0000014848.tif - Original CRS: EPSG:26913
# Original numTiles for id11639-0000000000-0000014848.tif: 70
# Adjusted numTiles for id11639-0000000000-0000014848.tif: 4 based on proportional area.
# Processing id11640.tif - Original CRS: EPSG:26918
# Processing id11642.tif - Original CRS: EPSG:26919
# Processing id11644.tif - Original CRS: EPSG:26918
# Processing id11645.tif - Original CRS: EPSG:26911
# Processing id11646.tif - Original CRS: EPSG:26918
# Processing id11649.tif - Original CRS: EPSG:26919
# Processing id1165.tif - Original CRS: EPSG:26915
# Processing id11650.tif - Original CRS: EPSG:26911
# Processing id11652.tif - Original CRS: EPSG:26914
# Processing id11653.tif - Original CRS: EPSG:26914
# Processing id11655.tif - Original CRS: EPSG:26914
# Processing id11656.tif - Original CRS: EPSG:26914
# Processing id11657.tif - Original CRS: EPSG:26919
# Processing id11658.tif - Original CRS: EPSG:26919
# Processing id1166.tif - Original CRS: EPSG:26914
# Processing id11661.tif - Original CRS: EPSG:26910
# Processing id11662.tif - Original CRS: EPSG:26913
# Warning: No matching polygon found for array ID 11662. Skipping.
# Processing id11663.tif - Original CRS: EPSG:26913
# Processing id11664.tif - Original CRS: EPSG:26918
# Processing id11665.tif - Original CRS: EPSG:26918
# Processing id11666.tif - Original CRS: EPSG:26918
# Processing id11668.tif - Original CRS: EPSG:26919
# Processing id11672.tif - Original CRS: EPSG:26915
# Warning: No matching polygon found for array ID 11672. Skipping.
# Processing id11674.tif - Original CRS: EPSG:26917
# Processing id11675.tif - Original CRS: EPSG:26919
# Processing id11686.tif - Original CRS: EPSG:26917
# Processing id11687.tif - Original CRS: EPSG:26914
# Processing id11689.tif - Original CRS: EPSG:26918
# Processing id11690.tif - Original CRS: EPSG:26911
# Processing id11693.tif - Original CRS: EPSG:26911
# Processing id11694.tif - Original CRS: EPSG:26911
# Processing id11697.tif - Original CRS: EPSG:26915
# Warning: No matching polygon found for array ID 11697. Skipping.
# Processing id11701.tif - Original CRS: EPSG:26913
# Processing id11702.tif - Original CRS: EPSG:26917
# Processing id11704.tif - Original CRS: EPSG:26917
# Processing id11705.tif - Original CRS: EPSG:26915
# Processing id11707.tif - Original CRS: EPSG:26918
# Processing id11710.tif - Original CRS: EPSG:26918
# Processing id11712.tif - Original CRS: EPSG:26917
# Processing id11713.tif - Original CRS: EPSG:26917
# Processing id11714.tif - Original CRS: EPSG:26918
# Processing id11716.tif - Original CRS: EPSG:26919
# Processing id11717.tif - Original CRS: EPSG:26917
# Processing id11719.tif - Original CRS: EPSG:26917
# Processing id11720.tif - Original CRS: EPSG:26918
# Processing id11721.tif - Original CRS: EPSG:26915
# Warning: No matching polygon found for array ID 11721. Skipping.
# Processing id11722.tif - Original CRS: EPSG:26914
# Processing id11723.tif - Original CRS: EPSG:26917
# Processing id11724.tif - Original CRS: EPSG:26917
# Processing id11725.tif - Original CRS: EPSG:26918
# Processing id11730.tif - Original CRS: EPSG:26919
# Processing id11731.tif - Original CRS: EPSG:26910
# Processing id11732.tif - Original CRS: EPSG:26910
# Processing id11735.tif - Original CRS: EPSG:26917
# Processing id11736.tif - Original CRS: EPSG:26918
# Processing id11739.tif - Original CRS: EPSG:26918
# Processing id11741.tif - Original CRS: EPSG:26917
# Processing id11742.tif - Original CRS: EPSG:26917
# Processing id11743.tif - Original CRS: EPSG:26918
# Processing id11744.tif - Original CRS: EPSG:26918
# Processing id11745.tif - Original CRS: EPSG:26918
# Processing id11753.tif - Original CRS: EPSG:26919
# Processing id11754.tif - Original CRS: EPSG:26917
# Processing id11756.tif - Original CRS: EPSG:26910
# Processing id11757.tif - Original CRS: EPSG:26913
# Processing id11758.tif - Original CRS: EPSG:26913
# Processing id11759.tif - Original CRS: EPSG:26913
# Processing id11760.tif - Original CRS: EPSG:26919
# Processing id11761.tif - Original CRS: EPSG:26917
# Processing id11762.tif - Original CRS: EPSG:26910
# Processing id11763.tif - Original CRS: EPSG:26918
# Processing id11772.tif - Original CRS: EPSG:26918
# Processing id11773.tif - Original CRS: EPSG:26916
# Processing id11776.tif - Original CRS: EPSG:26917
# Processing id11777.tif - Original CRS: EPSG:26917
# Processing id11778.tif - Original CRS: EPSG:26917
# Processing id11780.tif - Original CRS: EPSG:26917
# Processing id11781.tif - Original CRS: EPSG:26911
# Processing id11785.tif - Original CRS: EPSG:26918
# Processing id11787.tif - Original CRS: EPSG:26918
# Processing id11788.tif - Original CRS: EPSG:26918
# Processing id11789.tif - Original CRS: EPSG:26917
# Processing id11790.tif - Original CRS: EPSG:26918
# Processing id11791.tif - Original CRS: EPSG:26918
# Processing id11792.tif - Original CRS: EPSG:26918
# Processing id11793.tif - Original CRS: EPSG:26916
# Processing id11794.tif - Original CRS: EPSG:26918
# Processing id11795.tif - Original CRS: EPSG:26918
# Processing id11796.tif - Original CRS: EPSG:26918
# Processing id11797.tif - Original CRS: EPSG:26913
# Processing id118.tif - Original CRS: EPSG:26911
# Processing id11800.tif - Original CRS: EPSG:26917
# Processing id11801.tif - Original CRS: EPSG:26917
# Processing id11802.tif - Original CRS: EPSG:26917
# Processing id11804.tif - Original CRS: EPSG:26918
# Processing id11805.tif - Original CRS: EPSG:26917
# Processing id11806.tif - Original CRS: EPSG:26917
# Processing id11807.tif - Original CRS: EPSG:26917
# Processing id11808.tif - Original CRS: EPSG:26918
# Processing id11809.tif - Original CRS: EPSG:26918
# Processing id11810.tif - Original CRS: EPSG:26918
# Processing id11811.tif - Original CRS: EPSG:26918
# Processing id11813.tif - Original CRS: EPSG:26911
# Processing id11814.tif - Original CRS: EPSG:26915
# Warning: No matching polygon found for array ID 11814. Skipping.
# Processing id11817.tif - Original CRS: EPSG:26917
# Processing id11818.tif - Original CRS: EPSG:26913
# Warning: No matching polygon found for array ID 11818. Skipping.
# Processing id11819.tif - Original CRS: EPSG:26911
# Processing id11820.tif - Original CRS: EPSG:26918
# Processing id11821.tif - Original CRS: EPSG:26918
# Processing id11825.tif - Original CRS: EPSG:26917
# Processing id11826.tif - Original CRS: EPSG:26915
# Warning: No matching polygon found for array ID 11826. Skipping.
# Processing id11828.tif - Original CRS: EPSG:26918
# Processing id11829.tif - Original CRS: EPSG:26914
# Processing id11832.tif - Original CRS: EPSG:26918
# Processing id11833.tif - Original CRS: EPSG:26917
# Processing id11834.tif - Original CRS: EPSG:26917
# ...
# Processing id8821.tif - Original CRS: EPSG:26912
# Processing id8823.tif - Original CRS: EPSG:26913
# Processing id8828.tif - Original CRS: EPSG:26911
# Processing id8829.tif - Original CRS: EPSG:26910
# Processing id883.tif - Original CRS: EPSG:26918
# Processing id8831.tif - Original CRS: EPSG:26910
# Processing id884.tif - Original CRS: EPSG:26918
# Processing id8844.tif - Original CRS: EPSG:26919
# Processing id8848.tif - Original CRS: EPSG:26919
# Processing id8849.tif - Original CRS: EPSG:26911
# Processing id885.tif - Original CRS: EPSG:26918
# Processing id8851.tif - Original CRS: EPSG:26910
# Processing id8852.tif - Original CRS: EPSG:26914
# Processing id8855.tif - Original CRS: EPSG:26917
# Processing id8856.tif - Original CRS: EPSG:26918
# Processing id8865.tif - Original CRS: EPSG:26915
# Processing id8868.tif - Original CRS: EPSG:26918
# Processing id887.tif - Original CRS: EPSG:26918
# Processing id8873.tif - Original CRS: EPSG:26911
# Processing id8876.tif - Original CRS: EPSG:26917
# Processing id8878.tif - Original CRS: EPSG:26918
# Processing id8879.tif - Original CRS: EPSG:26911
# Processing id8882.tif - Original CRS: EPSG:26910
# Processing id8884.tif - Original CRS: EPSG:26916
# Processing id8885.tif - Original CRS: EPSG:26918
# Processing id8894.tif - Original CRS: EPSG:26919
# Processing id8896.tif - Original CRS: EPSG:26912
# Processing id8899.tif - Original CRS: EPSG:26911
# Processing id89.tif - Original CRS: EPSG:26910
# Processing id890.tif - Original CRS: EPSG:26918
# Processing id8905.tif - Original CRS: EPSG:26919
# Processing id8907.tif - Original CRS: EPSG:26918
# Processing id8908.tif - Original CRS: EPSG:26918
# Processing id8915.tif - Original CRS: EPSG:26916
# Processing id892.tif - Original CRS: EPSG:26918
# Processing id8924.tif - Original CRS: EPSG:26918
# Processing id8926.tif - Original CRS: EPSG:26914
# Processing id8929.tif - Original CRS: EPSG:26911
# Processing id8947.tif - Original CRS: EPSG:26916
# Processing id8948.tif - Original CRS: EPSG:26919
# Processing id895.tif - Original CRS: EPSG:26918
# Processing id8950.tif - Original CRS: EPSG:26916
# Processing id8951.tif - Original CRS: EPSG:26917
# Processing id8958.tif - Original CRS: EPSG:26918
# Processing id8975.tif - Original CRS: EPSG:26912
# Processing id8983.tif - Original CRS: EPSG:26918
# Processing id8993.tif - Original CRS: EPSG:26911
# Processing id8995.tif - Original CRS: EPSG:26910
# Processing id8997.tif - Original CRS: EPSG:26910
# Processing id9.tif - Original CRS: EPSG:26911
# Processing id9002.tif - Original CRS: EPSG:26914
# Processing id9004.tif - Original CRS: EPSG:26914
# Processing id9006.tif - Original CRS: EPSG:26915
# Processing id9008.tif - Original CRS: EPSG:26911
# Processing id901.tif - Original CRS: EPSG:26918
# Processing id902.tif - Original CRS: EPSG:26918
# Processing id9021.tif - Original CRS: EPSG:26917
# Processing id9023.tif - Original CRS: EPSG:26916
# Processing id9024.tif - Original CRS: EPSG:26918
# Processing id9026.tif - Original CRS: EPSG:26918
# Processing id9028.tif - Original CRS: EPSG:26919
# Processing id9041.tif - Original CRS: EPSG:26917
# Processing id9048.tif - Original CRS: EPSG:26910
# Processing id905.tif - Original CRS: EPSG:26918
# Processing id9054.tif - Original CRS: EPSG:26919
# Processing id906.tif - Original CRS: EPSG:26918
# Processing id9068.tif - Original CRS: EPSG:26917
# Processing id907.tif - Original CRS: EPSG:26918
# Processing id9085.tif - Original CRS: EPSG:26910
# Processing id9102.tif - Original CRS: EPSG:26911
# Processing id9107.tif - Original CRS: EPSG:26910
# Processing id9117.tif - Original CRS: EPSG:26912
# Processing id9129.tif - Original CRS: EPSG:26918
# Processing id913.tif - Original CRS: EPSG:26918
# Processing id9137.tif - Original CRS: EPSG:26911
# Processing id9153.tif - Original CRS: EPSG:26918
# Processing id917.tif - Original CRS: EPSG:26918
# Processing id9173.tif - Original CRS: EPSG:26912
# Processing id9176.tif - Original CRS: EPSG:26910
# Processing id9177.tif - Original CRS: EPSG:26914
# Processing id9183.tif - Original CRS: EPSG:26918
# Processing id9190.tif - Original CRS: EPSG:26910
# Processing id9194.tif - Original CRS: EPSG:26911
# Processing id9197.tif - Original CRS: EPSG:26911
# Processing id9202.tif - Original CRS: EPSG:26911
# Processing id9204.tif - Original CRS: EPSG:26919
# Processing id9205.tif - Original CRS: EPSG:26918
# Processing id922.tif - Original CRS: EPSG:26918
# Processing id9223.tif - Original CRS: EPSG:26911
# Processing id923.tif - Original CRS: EPSG:26918
# Processing id9237.tif - Original CRS: EPSG:26910
# Processing id9239.tif - Original CRS: EPSG:26917
# Processing id9242.tif - Original CRS: EPSG:26911
# Processing id9245.tif - Original CRS: EPSG:26911
# Processing id9246.tif - Original CRS: EPSG:26911
# Processing id9248.tif - Original CRS: EPSG:26916
# Processing id9249.tif - Original CRS: EPSG:26918
# Processing id925.tif - Original CRS: EPSG:26918
# Processing id9251.tif - Original CRS: EPSG:26911
# Processing id9252.tif - Original CRS: EPSG:26911
# Processing id9262.tif - Original CRS: EPSG:26918
# Processing id9263.tif - Original CRS: EPSG:26919
# Processing id9280.tif - Original CRS: EPSG:26918
# Processing id9282.tif - Original CRS: EPSG:26918
# Processing id9285.tif - Original CRS: EPSG:26916
# Processing id9291.tif - Original CRS: EPSG:26911
# Processing id9292.tif - Original CRS: EPSG:26918
# Processing id9297.tif - Original CRS: EPSG:26914
# Processing id9300.tif - Original CRS: EPSG:26911
# Processing id9301.tif - Original CRS: EPSG:26911
# Processing id9305.tif - Original CRS: EPSG:26911
# Processing id9311.tif - Original CRS: EPSG:26918
# Processing id9316.tif - Original CRS: EPSG:26918
# Processing id9320.tif - Original CRS: EPSG:26915
# Processing id9324.tif - Original CRS: EPSG:26917
# Processing id9329.tif - Original CRS: EPSG:26916
# Processing id933.tif - Original CRS: EPSG:26918
# Processing id9330.tif - Original CRS: EPSG:26918
# Processing id9337.tif - Original CRS: EPSG:26919
# Processing id9340.tif - Original CRS: EPSG:26917
# Processing id9342.tif - Original CRS: EPSG:26910
# Processing id9343.tif - Original CRS: EPSG:26914
# Processing id9345.tif - Original CRS: EPSG:26919
# Processing id9346.tif - Original CRS: EPSG:26911
# Processing id9347.tif - Original CRS: EPSG:26915
# Processing id9348.tif - Original CRS: EPSG:26918
# Processing id9349.tif - Original CRS: EPSG:26910
# Processing id9350.tif - Original CRS: EPSG:26918
# Processing id9351.tif - Original CRS: EPSG:26914
# Processing id9352.tif - Original CRS: EPSG:26911
# Processing id9353.tif - Original CRS: EPSG:26917
# Processing id9355.tif - Original CRS: EPSG:26918
# Processing id9356.tif - Original CRS: EPSG:26918
# Processing id9358.tif - Original CRS: EPSG:26911
# Processing id9359.tif - Original CRS: EPSG:26916
# Processing id936.tif - Original CRS: EPSG:26918
# Processing id9364.tif - Original CRS: EPSG:26917
# Processing id9365.tif - Original CRS: EPSG:26913
# Processing id9371.tif - Original CRS: EPSG:26910
# Processing id9375.tif - Original CRS: EPSG:26910
# Processing id9376.tif - Original CRS: EPSG:26919
# Processing id9379.tif - Original CRS: EPSG:26918
# Processing id9380.tif - Original CRS: EPSG:26918
# Processing id9382.tif - Original CRS: EPSG:26911
# Processing id9383.tif - Original CRS: EPSG:26910
# Processing id9384.tif - Original CRS: EPSG:26916
# Processing id9385.tif - Original CRS: EPSG:26919
# Processing id9387.tif - Original CRS: EPSG:26915
# Processing id9388.tif - Original CRS: EPSG:26918
# Processing id9389.tif - Original CRS: EPSG:26918
# Processing id939.tif - Original CRS: EPSG:26918
# Processing id9390.tif - Original CRS: EPSG:26914
# Processing id9391.tif - Original CRS: EPSG:26915
# Processing id9392.tif - Original CRS: EPSG:26918
# Processing id9393.tif - Original CRS: EPSG:26918
# Processing id9396.tif - Original CRS: EPSG:26916
# Processing id9397.tif - Original CRS: EPSG:26916
# Processing id9398.tif - Original CRS: EPSG:26919
# Processing id9399.tif - Original CRS: EPSG:26919
# Processing id9400.tif - Original CRS: EPSG:26919
# Processing id9401.tif - Original CRS: EPSG:26918
# Processing id9403.tif - Original CRS: EPSG:26917
# Processing id9404.tif - Original CRS: EPSG:26918
# Processing id9405.tif - Original CRS: EPSG:26918
# Processing id9407.tif - Original CRS: EPSG:26917
# Processing id9408.tif - Original CRS: EPSG:26910
# Processing id9409.tif - Original CRS: EPSG:26911
# Processing id941.tif - Original CRS: EPSG:26918
# Processing id9410.tif - Original CRS: EPSG:26915
# Processing id9414.tif - Original CRS: EPSG:26918
# Processing id9416.tif - Original CRS: EPSG:26918
# Processing id9417.tif - Original CRS: EPSG:26918
# Processing id942.tif - Original CRS: EPSG:26918
# Processing id9420.tif - Original CRS: EPSG:26912
# Processing id9433.tif - Original CRS: EPSG:26918
# Processing id9435.tif - Original CRS: EPSG:26914
# Processing id9437.tif - Original CRS: EPSG:26919
# Processing id9438.tif - Original CRS: EPSG:26916
# Processing id944.tif - Original CRS: EPSG:26918
# Processing id9448.tif - Original CRS: EPSG:26911
# Processing id945.tif - Original CRS: EPSG:26918
# Processing id9450.tif - Original CRS: EPSG:26911
# Processing id9451.tif - Original CRS: EPSG:26911
# Processing id9454.tif - Original CRS: EPSG:26919
# Processing id9457.tif - Original CRS: EPSG:26911
# Processing id9458.tif - Original CRS: EPSG:26912
# Processing id9459.tif - Original CRS: EPSG:26918
# Processing id9464.tif - Original CRS: EPSG:26914
# Processing id9465.tif - Original CRS: EPSG:26916
# Processing id9466.tif - Original CRS: EPSG:26910
# Processing id9467.tif - Original CRS: EPSG:26918
# Processing id9468.tif - Original CRS: EPSG:26910
# Processing id947.tif - Original CRS: EPSG:26918
# Processing id9476.tif - Original CRS: EPSG:26910
# Processing id9478.tif - Original CRS: EPSG:26910
# Processing id9480.tif - Original CRS: EPSG:26918
# Processing id9481.tif - Original CRS: EPSG:26917
# Processing id9484.tif - Original CRS: EPSG:26916
# Processing id9485.tif - Original CRS: EPSG:26911
# Processing id9493.tif - Original CRS: EPSG:26919
# Processing id9497.tif - Original CRS: EPSG:26917
# Processing id9499.tif - Original CRS: EPSG:26911
# Processing id9500.tif - Original CRS: EPSG:26913
# Processing id9501.tif - Original CRS: EPSG:26911
# Processing id9502.tif - Original CRS: EPSG:26912
# Processing id9503.tif - Original CRS: EPSG:26910
# Processing id9506.tif - Original CRS: EPSG:26916
# Processing id9507.tif - Original CRS: EPSG:26917
# Processing id9509.tif - Original CRS: EPSG:26917
# Processing id9517.tif - Original CRS: EPSG:26911
# Processing id9521.tif - Original CRS: EPSG:26912
# Processing id9522.tif - Original CRS: EPSG:26915
# Processing id9525.tif - Original CRS: EPSG:26915
# Processing id9531.tif - Original CRS: EPSG:26913
# Processing id9533.tif - Original CRS: EPSG:26918
# Processing id9535.tif - Original CRS: EPSG:26917
# Processing id9536.tif - Original CRS: EPSG:26917
# Processing id9537.tif - Original CRS: EPSG:26916
# Processing id9542.tif - Original CRS: EPSG:26919
# Processing id9543.tif - Original CRS: EPSG:26911
# Processing id9546.tif - Original CRS: EPSG:26911
# Processing id9547.tif - Original CRS: EPSG:26911
# Processing id9558.tif - Original CRS: EPSG:26919
# Processing id9559.tif - Original CRS: EPSG:26919
# Processing id9561.tif - Original CRS: EPSG:26917
# Processing id9565.tif - Original CRS: EPSG:26919
# Processing id9567.tif - Original CRS: EPSG:26911
# Processing id9569.tif - Original CRS: EPSG:26911
# Processing id957.tif - Original CRS: EPSG:26918
# Processing id9570.tif - Original CRS: EPSG:26916
# Processing id9572.tif - Original CRS: EPSG:26911
# Processing id9573.tif - Original CRS: EPSG:26911
# Processing id9578.tif - Original CRS: EPSG:26910
# Processing id958.tif - Original CRS: EPSG:26918
# Processing id9587.tif - Original CRS: EPSG:26910
# Processing id9595.tif - Original CRS: EPSG:26918
# Processing id9598.tif - Original CRS: EPSG:26918
# Processing id9599.tif - Original CRS: EPSG:26918
# Processing id96.tif - Original CRS: EPSG:26911
# Processing id960.tif - Original CRS: EPSG:26918
# Processing id9604.tif - Original CRS: EPSG:26910
# Processing id9608.tif - Original CRS: EPSG:26917
# Processing id9609.tif - Original CRS: EPSG:26918
# Processing id9615.tif - Original CRS: EPSG:26917
# Processing id9619.tif - Original CRS: EPSG:26917
# Processing id9622.tif - Original CRS: EPSG:26915
# Processing id9629.tif - Original CRS: EPSG:26910
# Processing id9630.tif - Original CRS: EPSG:26917
# Processing id9633.tif - Original CRS: EPSG:26918
# Processing id9637.tif - Original CRS: EPSG:26913
# Processing id9639.tif - Original CRS: EPSG:26919
# Processing id964.tif - Original CRS: EPSG:26918
# Processing id9644.tif - Original CRS: EPSG:26918
# Processing id9647.tif - Original CRS: EPSG:26910
# Processing id9648.tif - Original CRS: EPSG:26918
# Processing id965.tif - Original CRS: EPSG:26918
# Processing id9653.tif - Original CRS: EPSG:26918
# Processing id966.tif - Original CRS: EPSG:26917
# Processing id9664.tif - Original CRS: EPSG:26910
# Processing id9677.tif - Original CRS: EPSG:26917
# Processing id9681.tif - Original CRS: EPSG:26918
# Processing id9689.tif - Original CRS: EPSG:26918
# Processing id969.tif - Original CRS: EPSG:26918
# Processing id9691.tif - Original CRS: EPSG:26911
# Processing id9698.tif - Original CRS: EPSG:26918
# Processing id9706.tif - Original CRS: EPSG:26911
# Processing id9707.tif - Original CRS: EPSG:26917
# Processing id9708.tif - Original CRS: EPSG:26910
# Processing id971.tif - Original CRS: EPSG:26918
# Processing id9710.tif - Original CRS: EPSG:26918
# Processing id9711.tif - Original CRS: EPSG:26913
# Processing id9715.tif - Original CRS: EPSG:26919
# Processing id9719.tif - Original CRS: EPSG:26910
# Processing id9720.tif - Original CRS: EPSG:26918
# Processing id9725.tif - Original CRS: EPSG:26916
# Processing id9726.tif - Original CRS: EPSG:26918
# Processing id9729.tif - Original CRS: EPSG:26916
# Processing id9742.tif - Original CRS: EPSG:26910
# Processing id9743.tif - Original CRS: EPSG:26910
# Processing id975.tif - Original CRS: EPSG:26918
# Processing id9758.tif - Original CRS: EPSG:26918
# Processing id9760.tif - Original CRS: EPSG:26918
# Processing id977.tif - Original CRS: EPSG:26918
# Processing id9773.tif - Original CRS: EPSG:26911
# Processing id979.tif - Original CRS: EPSG:26918
# Processing id9793.tif - Original CRS: EPSG:26911
# Processing id9808.tif - Original CRS: EPSG:26910
# Processing id983.tif - Original CRS: EPSG:26918
# Processing id9836.tif - Original CRS: EPSG:26914
# Processing id9837.tif - Original CRS: EPSG:26919
# Processing id984.tif - Original CRS: EPSG:26918
# Processing id9840.tif - Original CRS: EPSG:26911
# Processing id9846.tif - Original CRS: EPSG:26919
# Processing id9848.tif - Original CRS: EPSG:26918
# Processing id985.tif - Original CRS: EPSG:26917
# Processing id9850.tif - Original CRS: EPSG:26919
# Processing id9851.tif - Original CRS: EPSG:26911
# Processing id9856.tif - Original CRS: EPSG:26912
# Processing id986.tif - Original CRS: EPSG:26918
# Processing id9860.tif - Original CRS: EPSG:26912
# Processing id9868.tif - Original CRS: EPSG:26911
# Processing id9870.tif - Original CRS: EPSG:26912
# Processing id9874.tif - Original CRS: EPSG:26911
# Processing id9876.tif - Original CRS: EPSG:26911
# Processing id988.tif - Original CRS: EPSG:26918
# Processing id9885.tif - Original CRS: EPSG:26916
# Processing id9888.tif - Original CRS: EPSG:26910
# Processing id989.tif - Original CRS: EPSG:26918
# Processing id9896.tif - Original CRS: EPSG:26911
# Processing id990.tif - Original CRS: EPSG:26917
# Processing id9901.tif - Original CRS: EPSG:26916
# Processing id9909.tif - Original CRS: EPSG:26917
# Processing id991.tif - Original CRS: EPSG:26918
# Processing id9912.tif - Original CRS: EPSG:26914
# Processing id9919.tif - Original CRS: EPSG:26916
# Processing id992.tif - Original CRS: EPSG:26917
# Processing id993.tif - Original CRS: EPSG:26918
# Processing id9933.tif - Original CRS: EPSG:26911
# Processing id9934.tif - Original CRS: EPSG:26911
# Processing id9936.tif - Original CRS: EPSG:26911
# Processing id9937.tif - Original CRS: EPSG:26919
# Processing id9940.tif - Original CRS: EPSG:26910
# Processing id9941.tif - Original CRS: EPSG:26918
# Processing id9952.tif - Original CRS: EPSG:26917
# Processing id9959.tif - Original CRS: EPSG:26919
# Processing id996.tif - Original CRS: EPSG:26918
# Processing id9962.tif - Original CRS: EPSG:26918
