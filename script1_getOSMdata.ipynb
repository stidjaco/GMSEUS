# %% [markdown]
# # Grab OpenStreetMap Data for Solar Panels and Arrays

# %% [markdown]
# ## Import Libraries

# %%
# Import gmseus utilities functions
import osmUtils as ou

# %% [markdown]
# ## Set Required Paths

# %%
# Set paths
wd = r'S:\Users\stidjaco\R_files\BigPanel'

# %% [markdown]
# ## Acquire Region-Wide Solar Array and Panel-Row OSM Data

# %%
# Process solar OSM data for an individual region
ou.processSolarOSMData('Rhode Island', 'USA', wd) # r'F:\Data\Planet_OSM\planet-251124.osm.pbf'
# Out:
# Rhode Island: Reading solar data from local PBF: F:\Data\Planet_OSM\planet-251124.osm.pbf
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Process solar OSM data for an individual region
# ----> 2 ou.processSolarOSMData('Rhode Island', 'USA', wd, r'F:\Data\Planet_OSM\planet-251124.osm.pbf')
#
# File s:\Users\stidjaco\R_files\BigPanel\Code\osmUtils.py:339, in processSolarOSMData(regionName, countryName, wd, osmPlanetPBF)
#     337     panelData, arrayData = getSolarOSMData(regionName, countryName)
#     338 else:
# --> 339     panelData, arrayData = getSolarOSMData(regionName, countryName, osmPlanetPBF=osmPlanetPBF)
#     341 #~~~~~~~~~~~~~~~~~~~~#
#     342 # Process Array Data # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     343 #~~~~~~~~~~~~~~~~~~~~#
#     344
# ...

# %% [markdown]
# ## Acquire Contry-Wide Solar Array and Panel-Row OSM Data

# %%
# Call the function to get OSM solar data for the entire country (CONUS)
ou.getCountrySolarOSMData('USA', wd)
ou.getCountrySolarOSMData('Canada', wd)
ou.getCountrySolarOSMData('Mexico', wd)
# Out:
# Alaska: Attempting to retrieve solar data...
# f:\Python_Envs\BigPanel\Lib\site-packages\osmnx\_overpass.py:254: UserWarning: This area is 1,886 times your configured Overpass max query area size. It will automatically be divided up into multiple sub-queries accordingly. This may take a long time.
#   multi_poly_proj = utils_geo._consolidate_subdivide_geometry(poly_proj)
